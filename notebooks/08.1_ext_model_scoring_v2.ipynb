# %% [markdown]
# # Model Scoring eval v2
#
# This version works on the original template to evaluate newer models to replace the current deprecated llama model. It compares and evaluate different **models** using the winning prompt from prompt evaluation.
#
# 1. openai/gpt-oss-20b - Groq’s 8B replacement. Production. Fast (~1000 tok/s). Cheap. Closest “drop-in” for latency and cost.
# 2. openai/gpt-oss-120b - Groq’s 70B-class replacement. Production. Better instruction following, more risk of over-shortening.
# 3. qwen/qwen3.6-27b - Preview. Stronger German/easy-language rewrite is plausible. More expensive, and preview models can disappear.
#
# ## What This Notebook Does
#
# 1. **Fixed Prompt** - Uses Prompt B (Structured) - the winner from prompt evaluation
# 2. **Model Comparison** - Tests multiple models on the same prompt and test texts
# 3. **Output Quality Metrics** - Measures how well each model produces Easy Language output
# 4. **A/B Testing** - Directly compare two models to pick the winner
#
# ## Key Difference from Prompt Evaluation
#
# | Template | Fixed Variable | Changeable Variable |
# |----------|----------------|---------------------|
# | Prompt Evaluation | Model | Prompts |
# | **Model Scoring** | **Prompt** | **Models** |

# %% [markdown]
# ---
# # 1. Setup

# %%
import os
import re
import time
from dotenv import load_dotenv, find_dotenv
from groq import Groq
from IPython.display import display, HTML, Markdown
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load environment
found_path = find_dotenv(usecwd=True)
if found_path:
    load_dotenv(found_path, override=True)
    print(f"✅ Loaded .env from: {found_path}")

# Initialize Groq
groq_client = None
if os.getenv("GROQ_API_KEY"):
    groq_client = Groq(api_key=os.getenv("GROQ_API_KEY"))
    print("✅ Groq Client Ready")
else:
    print("⚠️ GROQ_API_KEY not found")
# Out:
# ✅ Loaded .env from: /Users/esmahoney/Projects/klartext/klartext/.env
# ✅ Groq Client Ready

# %% [markdown]
# ---
# # 2. Configuration
#
# ### Models to Compare

# %%
# =============================================
# MODELS TO COMPARE
# =============================================

MODELS = {
    "Model A (replacement 8B)": "openai/gpt-oss-20b",
    "Model B (replacement 70B)": "openai/gpt-oss-120b",
    "Model C (preview 27B)": "qwen/qwen3.6-27b",
    
}

# Additional models you can add:
# "Model C (Gemma)": "gemma2-9b-it",
# "Model D (Mixtral)": "mixtral-8x7b-32768",

print(f"🤖 Loaded {len(MODELS)} models to compare:")
for name, model_id in MODELS.items():
    print(f"   • {name}: {model_id}")
# Out:
# 🤖 Loaded 3 models to compare:
#    • Model A (replacement 8B): openai/gpt-oss-20b
#    • Model B (replacement 70B): openai/gpt-oss-120b
#    • Model C (preview 27B): qwen/qwen3.6-27b

# %% [markdown]
# ### Fixed Prompt (Winner: Prompt B - Structured)
#
# This prompt won the prompt evaluation and will be used for all model comparisons.

# %%
# =============================================
# FIXED PROMPT (Prompt B - Structured)
# Winner from prompt evaluation
# =============================================

SYSTEM_PROMPT = """# Identity

You are an expert in plain language writing.
You specialise in rewriting text to be accessible 
to people with learning disabilities or low literacy.

# Core Task 

* Rewrite the input text to be extremely simple and easy to understand.
* Keep the same meaning as the original text.

# Constraints

* Do NOT include any introductory or concluding text (e.g., "Here is the simplified text").
* Output ONLY the simplified text.
* Never output any XML/HTML tags or attributes (no <...>, no id=...).

# Structure & Formatting Rules

* Use clear structure.
* Use bullet points for steps, lists, or multiple items. Otherwise prefer short sentences.
* Add blank lines between every paragraph.

# Plain Language Rules
# Sentence & Length Rules

* Use very short sentences (maximum 10 words per sentence).
* Break up long sentences.
* Keep subjects and verbs close together.

# Vocabulary & Wording Rules

* Use simple, familiar words. Avoid technical, foreign, or formal terms.
* Explain any uncommon or necessary technical words or abbreviations in parentheses the first time they appear.
* Explain complex ideas or uncommon nouns in parentheses.
* Use positive wording. Avoid negations and never use double negatives.
* Replace abstract nouns with concrete, active verbs.

# Tone & Audience Rules

* Prefer active voice. Avoid passive voice whenever possible.
* Address the reader directly using "you".
* Use a friendly, neutral tone.
* Avoid bureaucratic, legalistic, or commanding language.

# Consistency Rules

* Remove filler words and unnecessary details. Keep only essential information.
* Use the same words consistently. Do not switch terms for the same thing.

# Examples
# The following are example pairs.
# Learn the style and constraints from them.
# Do NOT copy the XML tags into your output.

<examples>

  <example id="1">
    <original_text>
    Upon arrival at the facility, visitors are required to sign in at the front desk and present valid photo identification.
    </original_text>

    <simplified_text>
    When you arrive:

    * Go to the front desk.
    * Sign in with your name.
    * Show your photo ID.
    </simplified_text>
  </example>

  <example id="2">
    <original_text>
    The medication should be administered twice daily with food to minimize potential gastrointestinal discomfort.
    </original_text>

    <simplified_text>
    Take this medicine two times every day.

    Eat food when you take it. This helps your stomach feel better.
    </simplified_text>
  </example>

</examples>

Rewrite this text in simple language:"""

print("📝 Fixed prompt loaded: Prompt B (Structured)")
print(f"   Length: {len(SYSTEM_PROMPT)} characters")
# Out:
# 📝 Fixed prompt loaded: Prompt B (Structured)
#    Length: 2575 characters

# %% [markdown]
# ### Test Texts

# %%
# Test texts to evaluate models on
TEST_TEXTS = {
    "Legal": """The obligations contained herein shall remain in full force and effect indefinitely, 
notwithstanding the termination of this Agreement, until such time as the Confidential Information 
no longer qualifies as confidential under applicable law.""",

    "Medical": """Patients should take the prescribed medication twice daily with food to minimize 
gastrointestinal discomfort. If adverse reactions occur, discontinue use immediately and consult 
your healthcare provider.""",

    "Bureaucratic": """For the application of housing benefit, a fully completed application form 
must be submitted to the responsible authority. The required proof of income and the rent 
certificate must be attached. Processing time is usually six to eight weeks."""
}

print(f"📄 Loaded {len(TEST_TEXTS)} test texts")
# Out:
# 📄 Loaded 3 test texts

# %% [markdown]
# ### Output Quality Metrics

# %%
# =============================================
# OUTPUT QUALITY METRICS
# =============================================

OUTPUT_METRICS = {
    "short_sentences": {
        "name": "Short Sentences",
        "description": "Maximum 10 words per sentence",
        "weight": 2,
        "check": lambda text: max([len(s.split()) for s in re.split(r'[.!?]', text) if s.strip()], default=0)
    },
    "uses_bullets": {
        "name": "Uses Bullet Points",
        "description": "Uses bullet points or numbered lists",
        "weight": 1,
        "check": lambda text: bool(re.search(r'[•\-\*]\s|^\d+\.\s', text, re.MULTILINE))
    },
    "has_paragraphs": {
        "name": "Clear Paragraphs",
        "description": "Has blank lines between sections",
        "weight": 1,
        "check": lambda text: '\n\n' in text
    },
    "no_intro_text": {
        "name": "No Intro/Outro Text",
        "description": "Starts directly without meta-text",
        "weight": 1,
        "check": lambda text: not bool(re.match(r'^(Here\'s|Here is|This is|The following|Sure|Certainly)', text.strip(), re.IGNORECASE))
    },
    "no_xml_tags": {
        "name": "No XML/HTML Tags",
        "description": "No markup in output",
        "weight": 1,
        "check": lambda text: not bool(re.search(r'<[^>]+>', text))
    }
}

print(f"📊 Output metrics: {len(OUTPUT_METRICS)}")
# Out:
# 📊 Output metrics: 5

# %% [markdown]
# ---
# # 3. Helper Functions

# %%
def get_completion(text: str, model_id: str) -> str:
    """Call a specific model with the fixed prompt."""
    if not groq_client:
        return "[No API Client]"

    request_kwargs = {
        "model": model_id,
        "messages": [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": text}
        ],
        "temperature": 0.1,
    }

    # GPT-OSS and Qwen 3.6 are reasoning models. Keep scored text as the rewrite only.
    extra_body = {"include_reasoning": False}
    if model_id.startswith("qwen/"):
        extra_body["reasoning_effort"] = "none"
    elif "gpt-oss" in model_id:
        extra_body["reasoning_effort"] = "low"
    request_kwargs["extra_body"] = extra_body

    try:
        response = groq_client.chat.completions.create(**request_kwargs)
        content = response.choices[0].message.content or ""
        content = re.sub(r"<think>.*?</think>", "", content, flags=re.DOTALL).strip()
        return content
    except Exception as e:
        return f"[Error: {e}]"


def evaluate_output_quality(output: str) -> dict:
    """Evaluate the model output."""
    results = {}
    total_score = 0
    max_score = 0
    
    for metric_id, metric in OUTPUT_METRICS.items():
        check_result = metric["check"](output)
        weight = metric["weight"]
        max_score += weight
        
        if metric_id == "short_sentences":
            passed = check_result <= 10
            results[metric_id] = {"pass": passed, "value": check_result, "weight": weight}
        else:
            passed = bool(check_result)
            results[metric_id] = {"pass": passed, "weight": weight}
        
        if passed:
            total_score += weight
    
    results["_score"] = total_score / max_score if max_score > 0 else 0
    return results


def tfidf_similarity(text1: str, text2: str) -> float:
    """Calculate TF-IDF similarity between texts."""
    try:
        vectorizer = TfidfVectorizer(lowercase=True)
        matrix = vectorizer.fit_transform([text1, text2])
        return round(cosine_similarity(matrix[0:1], matrix[1:2])[0][0], 3)
    except:
        return 0.0

# %%
def display_model_comparison(results: dict, test_name: str):
    """Display side-by-side comparison of models with checkboxes."""
    
    html = f"""<div style='background:#1a1a2e; padding:15px; border-radius:8px; margin:10px 0;'>
    <h3 style='color:#eee; margin:0 0 15px 0;'>📄 Test: {test_name}</h3>
    <div style='display:flex; gap:10px; flex-wrap:wrap;'>"""
    
    for model_name, data in results.items():
        output_eval = data["output_eval"]
        output_score = output_eval["_score"]
        similarity = data["similarity"]
        
        # Count passed metrics
        output_passed = sum(1 for k, v in output_eval.items() if k != "_score" and v.get("pass"))
        output_total = len([k for k in output_eval if k != "_score"])
        
        score_color = "#4ade80" if output_score >= 0.8 else "#fbbf24" if output_score >= 0.6 else "#f87171"
        sim_color = "#4ade80" if similarity >= 0.4 else "#fbbf24" if similarity >= 0.2 else "#f87171"
        
        html += f"""
        <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
            <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
                <strong style='color:#e0e0e0; font-size:14px;'>{model_name}</strong>
                <span style='background:{score_color}; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
                    {output_score:.0%}
                </span>
            </div>
            
            <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
                <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>{data["output"][:500]}{'...' if len(data["output"]) > 500 else ''}</pre>
            </div>
            
            <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
                <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
                <span style='color:{sim_color}; font-size:12px; font-weight:bold;'>{similarity:.1%}</span>
            </div>
            
            <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics ({output_passed}/{output_total})</div>
            <div style='font-size:11px;'>"""
        
        # Output metric checkboxes
        for metric_id, result in output_eval.items():
            if metric_id == "_score":
                continue
            icon = "✅" if result["pass"] else "❌"
            metric_name = OUTPUT_METRICS[metric_id]["name"]
            value_str = f" ({result.get('value', '')}w)" if metric_id == "short_sentences" else ""
            html += f"<div style='color:#aaa;'>{icon} {metric_name}{value_str}</div>"
        
        html += """</div>
        </div>"""
    
    html += "</div></div>"
    display(HTML(html))

# %%
def display_model_scorecard(all_results: dict):
    """Display overall scorecard for all models."""
    
    # Aggregate scores
    model_scores = {name: {"output": [], "similarity": []} for name in MODELS.keys()}
    
    for test_name, models in all_results.items():
        for model_name, data in models.items():
            model_scores[model_name]["output"].append(data["output_eval"]["_score"])
            model_scores[model_name]["similarity"].append(data["similarity"])
    
    html = """<div style='background:#1a1a2e; padding:20px; border-radius:8px; margin:20px 0;'>
    <h2 style='color:#eee; margin:0 0 15px 0;'>🏆 Model Scorecard</h2>
    <table style='width:100%; border-collapse:collapse;'>
        <tr style='background:#0f3460;'>
            <th style='color:#eee; padding:12px; text-align:left;'>Model</th>
            <th style='color:#eee; padding:12px; text-align:center;'>Model ID</th>
            <th style='color:#eee; padding:12px; text-align:center;'>Avg Quality</th>
            <th style='color:#eee; padding:12px; text-align:center;'>Avg Similarity</th>
            <th style='color:#eee; padding:12px; text-align:center;'>Combined</th>
            <th style='color:#eee; padding:12px; text-align:center;'>Rank</th>
        </tr>"""
    
    # Calculate combined scores and rank
    rankings = []
    for model_name in MODELS.keys():
        output_avg = sum(model_scores[model_name]["output"]) / len(model_scores[model_name]["output"])
        sim_avg = sum(model_scores[model_name]["similarity"]) / len(model_scores[model_name]["similarity"])
        combined = (output_avg * 0.7) + (sim_avg * 0.3)
        rankings.append((model_name, MODELS[model_name], output_avg, sim_avg, combined))
    
    rankings.sort(key=lambda x: x[4], reverse=True)
    
    for rank, (model_name, model_id, output_avg, sim_avg, combined) in enumerate(rankings, 1):
        score_color = "#4ade80" if combined >= 0.7 else "#fbbf24" if combined >= 0.5 else "#f87171"
        rank_icon = "🥇" if rank == 1 else "🥈" if rank == 2 else "🥉" if rank == 3 else f"#{rank}"
        
        html += f"""
        <tr style='border-bottom:1px solid #333;'>
            <td style='color:#ddd; padding:12px;'><strong>{model_name}</strong></td>
            <td style='color:#888; padding:12px; text-align:center; font-family:monospace; font-size:11px;'>{model_id}</td>
            <td style='color:#aaa; padding:12px; text-align:center;'>{output_avg:.0%}</td>
            <td style='color:#aaa; padding:12px; text-align:center;'>{sim_avg:.1%}</td>
            <td style='padding:12px; text-align:center;'>
                <span style='background:{score_color}; color:#000; padding:4px 12px; border-radius:12px;'>{combined:.0%}</span>
            </td>
            <td style='color:#eee; padding:12px; text-align:center; font-size:18px;'>{rank_icon}</td>
        </tr>"""
    
    html += "</table></div>"
    display(HTML(html))
    
    return rankings

# %% [markdown]
# ---
# # 4. Run Model Evaluation
#
# Compare all models on each test text using the fixed prompt.

# %%
print(f"🔄 Evaluating {len(MODELS)} models on {len(TEST_TEXTS)} test texts...")
print(f"📝 Using fixed prompt: Prompt B (Structured)\n")

all_results = {}

for test_name, test_text in TEST_TEXTS.items():
    all_results[test_name] = {}
    
    for model_name, model_id in MODELS.items():
        print(f"  → {test_name} | {model_name}...", end=" ")
        
        # Get model output
        output = get_completion(test_text, model_id)
        
        # Evaluate output quality
        output_eval = evaluate_output_quality(output)
        
        # Calculate meaning preservation
        similarity = tfidf_similarity(test_text, output)
        
        all_results[test_name][model_name] = {
            "model_id": model_id,
            "output": output,
            "output_eval": output_eval,
            "similarity": similarity
        }
        
        print(f"✓ ({output_eval['_score']:.0%})")
        time.sleep(0.5)
    
    # Display comparison for this test
    display_model_comparison(all_results[test_name], test_name)

print("\n✅ Evaluation complete!")
# Out:
# 🔄 Evaluating 3 models on 3 test texts...
# 📝 Using fixed prompt: Prompt B (Structured)
#
#   → Legal | Model A (replacement 8B)... ✓ (33%)
#   → Legal | Model B (replacement 70B)... ✓ (50%)
#   → Legal | Model C (preview 27B)... ✓ (50%)
# <div style='background:#1a1a2e; padding:15px; border-radius:8px; margin:10px 0;'>
#     <h3 style='color:#eee; margin:0 0 15px 0;'>📄 Test: Legal</h3>
#     <div style='display:flex; gap:10px; flex-wrap:wrap;'>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
#                 <strong style='color:#e0e0e0; font-size:14px;'>Model A (replacement 8B)</strong>
#                 <span style='background:#f87171; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
#                     33%
#                 </span>
#             </div>
#
#             <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
#                 <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>Your duties stay active forever, even after this agreement ends.
# They keep working until the confidential information is no longer protected by law.</pre>
#             </div>
#
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
#                 <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
#                 <span style='color:#fbbf24; font-size:12px; font-weight:bold;'>24.5%</span>
#             </div>
#
#             <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics (2/5)</div>
#             <div style='font-size:11px;'><div style='color:#aaa;'>❌ Short Sentences (13w)</div><div style='color:#aaa;'>❌ Uses Bullet Points</div><div style='color:#aaa;'>❌ Clear Paragraphs</div><div style='color:#aaa;'>✅ No Intro/Outro Text</div><div style='color:#aaa;'>✅ No XML/HTML Tags</div></div>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
#                 <strong style='color:#e0e0e0; font-size:14px;'>Model B (replacement 70B)</strong>
#                 <span style='background:#f87171; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
#                     50%
#                 </span>
#             </div>
#
#             <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
#                 <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>The duties stay in force forever.
#
# They keep working even after this agreement ends.
#
# They stop only when the secret information is no longer secret under the law.</pre>
#             </div>
#
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
#                 <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
#                 <span style='color:#fbbf24; font-size:12px; font-weight:bold;'>28.9%</span>
#             </div>
#
#             <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics (3/5)</div>
#             <div style='font-size:11px;'><div style='color:#aaa;'>❌ Short Sentences (14w)</div><div style='color:#aaa;'>❌ Uses Bullet Points</div><div style='color:#aaa;'>✅ Clear Paragraphs</div><div style='color:#aaa;'>✅ No Intro/Outro Text</div><div style='color:#aaa;'>✅ No XML/HTML Tags</div></div>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
#                 <strong style='color:#e0e0e0; font-size:14px;'>Model C (preview 27B)</strong>
#                 <span style='background:#f87171; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
#                     50%
#                 </span>
#             </div>
#
#             <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
#                 <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>Your duty to keep secrets lasts forever.
#
# This rule stays even if the contract ends.
#
# You must keep the information secret.
#
# You can stop when the law says it is no longer secret.</pre>
#             </div>
#
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
#                 <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
#                 <span style='color:#f87171; font-size:12px; font-weight:bold;'>19.1%</span>
#             </div>
#
#             <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics (3/5)</div>
#             <div style='font-size:11px;'><div style='color:#aaa;'>❌ Short Sentences (12w)</div><div style='color:#aaa;'>❌ Uses Bullet Points</div><div style='color:#aaa;'>✅ Clear Paragraphs</div><div style='color:#aaa;'>✅ No Intro/Outro Text</div><div style='color:#aaa;'>✅ No XML/HTML Tags</div></div>
#         </div></div></div>
#   → Medical | Model A (replacement 8B)... ✓ (50%)
#   → Medical | Model B (replacement 70B)... ✓ (67%)
#   → Medical | Model C (preview 27B)... ✓ (83%)
# <div style='background:#1a1a2e; padding:15px; border-radius:8px; margin:10px 0;'>
#     <h3 style='color:#eee; margin:0 0 15px 0;'>📄 Test: Medical</h3>
#     <div style='display:flex; gap:10px; flex-wrap:wrap;'>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
#                 <strong style='color:#e0e0e0; font-size:14px;'>Model A (replacement 8B)</strong>
#                 <span style='background:#f87171; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
#                     50%
#                 </span>
#             </div>
#
#             <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
#                 <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>Take the medicine twice a day.
#
# Eat food when you take it. This helps your stomach feel better.
#
# If you feel sick or have bad reactions, stop taking it right away. Call your doctor.</pre>
#             </div>
#
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
#                 <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
#                 <span style='color:#f87171; font-size:12px; font-weight:bold;'>15.9%</span>
#             </div>
#
#             <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics (3/5)</div>
#             <div style='font-size:11px;'><div style='color:#aaa;'>❌ Short Sentences (13w)</div><div style='color:#aaa;'>❌ Uses Bullet Points</div><div style='color:#aaa;'>✅ Clear Paragraphs</div><div style='color:#aaa;'>✅ No Intro/Outro Text</div><div style='color:#aaa;'>✅ No XML/HTML Tags</div></div>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
#                 <strong style='color:#e0e0e0; font-size:14px;'>Model B (replacement 70B)</strong>
#                 <span style='background:#fbbf24; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
#                     67%
#                 </span>
#             </div>
#
#             <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
#                 <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>Take the medicine two times each day.
#
# Eat food when you take it. This helps your stomach feel better.
#
# If you feel bad after taking it:
#
# * Stop taking the medicine right away.
# * Call your doctor.</pre>
#             </div>
#
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
#                 <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
#                 <span style='color:#f87171; font-size:12px; font-weight:bold;'>12.6%</span>
#             </div>
#
#             <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics (4/5)</div>
#             <div style='font-size:11px;'><div style='color:#aaa;'>❌ Short Sentences (14w)</div><div style='color:#aaa;'>✅ Uses Bullet Points</div><div style='color:#aaa;'>✅ Clear Paragraphs</div><div style='color:#aaa;'>✅ No Intro/Outro Text</div><div style='color:#aaa;'>✅ No XML/HTML Tags</div></div>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
#                 <strong style='color:#e0e0e0; font-size:14px;'>Model C (preview 27B)</strong>
#                 <span style='background:#4ade80; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
#                     83%
#                 </span>
#             </div>
#
#             <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
#                 <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>Take your medicine two times a day.
#
# Eat food when you take it. This helps your stomach.
#
# Stop taking the medicine if you feel sick.
#
# Call your doctor right away.</pre>
#             </div>
#
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
#                 <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
#                 <span style='color:#f87171; font-size:12px; font-weight:bold;'>14.5%</span>
#             </div>
#
#             <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics (4/5)</div>
#             <div style='font-size:11px;'><div style='color:#aaa;'>✅ Short Sentences (8w)</div><div style='color:#aaa;'>❌ Uses Bullet Points</div><div style='color:#aaa;'>✅ Clear Paragraphs</div><div style='color:#aaa;'>✅ No Intro/Outro Text</div><div style='color:#aaa;'>✅ No XML/HTML Tags</div></div>
#         </div></div></div>
#   → Bureaucratic | Model A (replacement 8B)... ✓ (67%)
#   → Bureaucratic | Model B (replacement 70B)... ✓ (67%)
#   → Bureaucratic | Model C (preview 27B)... ✓ (83%)
# <div style='background:#1a1a2e; padding:15px; border-radius:8px; margin:10px 0;'>
#     <h3 style='color:#eee; margin:0 0 15px 0;'>📄 Test: Bureaucratic</h3>
#     <div style='display:flex; gap:10px; flex-wrap:wrap;'>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
#                 <strong style='color:#e0e0e0; font-size:14px;'>Model A (replacement 8B)</strong>
#                 <span style='background:#fbbf24; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
#                     67%
#                 </span>
#             </div>
#
#             <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
#                 <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>When you apply for housing help:
#
# * Fill out the whole application form.
# * Attach proof of your income.
# * Attach the rent certificate.
#
# The office will take about six to eight weeks to finish your application.</pre>
#             </div>
#
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
#                 <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
#                 <span style='color:#4ade80; font-size:12px; font-weight:bold;'>43.7%</span>
#             </div>
#
#             <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics (4/5)</div>
#             <div style='font-size:11px;'><div style='color:#aaa;'>❌ Short Sentences (13w)</div><div style='color:#aaa;'>✅ Uses Bullet Points</div><div style='color:#aaa;'>✅ Clear Paragraphs</div><div style='color:#aaa;'>✅ No Intro/Outro Text</div><div style='color:#aaa;'>✅ No XML/HTML Tags</div></div>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
#                 <strong style='color:#e0e0e0; font-size:14px;'>Model B (replacement 70B)</strong>
#                 <span style='background:#fbbf24; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
#                     67%
#                 </span>
#             </div>
#
#             <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
#                 <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>When you apply for housing benefit:
#
# * Fill out the whole form.
# * Send it to the right office.
# * Add proof of your income.
# * Add the rent certificate.
#
# The office will usually take six to eight weeks to decide.</pre>
#             </div>
#
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
#                 <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
#                 <span style='color:#4ade80; font-size:12px; font-weight:bold;'>44.7%</span>
#             </div>
#
#             <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics (4/5)</div>
#             <div style='font-size:11px;'><div style='color:#aaa;'>❌ Short Sentences (12w)</div><div style='color:#aaa;'>✅ Uses Bullet Points</div><div style='color:#aaa;'>✅ Clear Paragraphs</div><div style='color:#aaa;'>✅ No Intro/Outro Text</div><div style='color:#aaa;'>✅ No XML/HTML Tags</div></div>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:10px;'>
#                 <strong style='color:#e0e0e0; font-size:14px;'>Model C (preview 27B)</strong>
#                 <span style='background:#4ade80; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>
#                     83%
#                 </span>
#             </div>
#
#             <div style='background:#1a1a2e; padding:8px; border-radius:4px; margin-bottom:10px; max-height:180px; overflow-y:auto;'>
#                 <pre style='color:#ddd; font-size:11px; white-space:pre-wrap; margin:0;'>You want housing benefit.
#
# You must send a form.
#
# Fill in the whole form.
#
# Send it to the right office.
#
# Add proof of your income.
#
# Add your rent certificate.
#
# It takes six to eight weeks.</pre>
#             </div>
#
#             <div style='display:flex; justify-content:space-between; align-items:center; margin-bottom:8px;'>
#                 <span style='color:#888; font-size:10px;'>TF-IDF Similarity:</span>
#                 <span style='color:#fbbf24; font-size:12px; font-weight:bold;'>34.7%</span>
#             </div>
#
#             <div style='color:#888; font-size:10px; margin-bottom:5px; text-transform:uppercase;'>Quality Metrics (4/5)</div>
#             <div style='font-size:11px;'><div style='color:#aaa;'>✅ Short Sentences (6w)</div><div style='color:#aaa;'>❌ Uses Bullet Points</div><div style='color:#aaa;'>✅ Clear Paragraphs</div><div style='color:#aaa;'>✅ No Intro/Outro Text</div><div style='color:#aaa;'>✅ No XML/HTML Tags</div></div>
#         </div></div></div>
# ✅ Evaluation complete!

# %% [markdown]
# ---
# # 5. Overall Scorecard
#
# See which model performs best overall.

# %%
rankings = display_model_scorecard(all_results)

# Winner announcement
winner = rankings[0]
print(f"\n🏆 Winner: {winner[0]} ({winner[1]})")
print(f"   Quality: {winner[2]:.0%} | Similarity: {winner[3]:.1%} | Combined: {winner[4]:.0%}")
# Out:
# <div style='background:#1a1a2e; padding:20px; border-radius:8px; margin:20px 0;'>
#     <h2 style='color:#eee; margin:0 0 15px 0;'>🏆 Model Scorecard</h2>
#     <table style='width:100%; border-collapse:collapse;'>
#         <tr style='background:#0f3460;'>
#             <th style='color:#eee; padding:12px; text-align:left;'>Model</th>
#             <th style='color:#eee; padding:12px; text-align:center;'>Model ID</th>
#             <th style='color:#eee; padding:12px; text-align:center;'>Avg Quality</th>
#             <th style='color:#eee; padding:12px; text-align:center;'>Avg Similarity</th>
#             <th style='color:#eee; padding:12px; text-align:center;'>Combined</th>
#             <th style='color:#eee; padding:12px; text-align:center;'>Rank</th>
#         </tr>
#         <tr style='border-bottom:1px solid #333;'>
#             <td style='color:#ddd; padding:12px;'><strong>Model C (preview 27B)</strong></td>
#             <td style='color:#888; padding:12px; text-align:center; font-family:monospace; font-size:11px;'>qwen/qwen3.6-27b</td>
#             <td style='color:#aaa; padding:12px; text-align:center;'>72%</td>
#             <td style='color:#aaa; padding:12px; text-align:center;'>22.8%</td>
#             <td style='padding:12px; text-align:center;'>
#                 <span style='background:#fbbf24; color:#000; padding:4px 12px; border-radius:12px;'>57%</span>
#             </td>
#             <td style='color:#eee; padding:12px; text-align:center; font-size:18px;'>🥇</td>
#         </tr>
#         <tr style='border-bottom:1px solid #333;'>
#             <td style='color:#ddd; padding:12px;'><strong>Model B (replacement 70B)</strong></td>
#             <td style='color:#888; padding:12px; text-align:center; font-family:monospace; font-size:11px;'>openai/gpt-oss-120b</td>
#             <td style='color:#aaa; padding:12px; text-align:center;'>61%</td>
#             <td style='color:#aaa; padding:12px; text-align:center;'>28.7%</td>
#             <td style='padding:12px; text-align:center;'>
#                 <span style='background:#fbbf24; color:#000; padding:4px 12px; border-radius:12px;'>51%</span>
#             </td>
#             <td style='color:#eee; padding:12px; text-align:center; font-size:18px;'>🥈</td>
#         </tr>
#         <tr style='border-bottom:1px solid #333;'>
#             <td style='color:#ddd; padding:12px;'><strong>Model A (replacement 8B)</strong></td>
#             <td style='color:#888; padding:12px; text-align:center; font-family:monospace; font-size:11px;'>openai/gpt-oss-20b</td>
#             <td style='color:#aaa; padding:12px; text-align:center;'>50%</td>
#             <td style='color:#aaa; padding:12px; text-align:center;'>28.0%</td>
#             <td style='padding:12px; text-align:center;'>
#                 <span style='background:#f87171; color:#000; padding:4px 12px; border-radius:12px;'>43%</span>
#             </td>
#             <td style='color:#eee; padding:12px; text-align:center; font-size:18px;'>🥉</td>
#         </tr></table></div>
# 🏆 Winner: Model C (preview 27B) (qwen/qwen3.6-27b)
#    Quality: 72% | Similarity: 22.8% | Combined: 57%

# %% [markdown]
# ---
# # 6. Detailed Metrics Breakdown
#
# See exactly which metrics each model passes or fails.

# %%
def display_detailed_metrics(all_results: dict):
    """Show detailed metric breakdown per model."""
    
    # Aggregate metrics across all tests
    output_metrics_agg = {name: {m: 0 for m in OUTPUT_METRICS} for name in MODELS}
    num_tests = len(TEST_TEXTS)
    
    for test_name, models in all_results.items():
        for model_name, data in models.items():
            for m in OUTPUT_METRICS:
                if data["output_eval"].get(m, {}).get("pass"):
                    output_metrics_agg[model_name][m] += 1
    
    # Display output metrics
    html = """<div style='background:#1a1a2e; padding:20px; border-radius:8px; margin:20px 0;'>
    <h3 style='color:#eee; margin:0 0 15px 0;'>📊 Output Quality Metrics (per test)</h3>
    <table style='width:100%; border-collapse:collapse; font-size:13px;'>
        <tr style='background:#0f3460;'>
            <th style='color:#eee; padding:8px; text-align:left;'>Metric</th>"""
    
    for name in MODELS:
        short_name = name.split("(")[0].strip()
        html += f"<th style='color:#eee; padding:8px; text-align:center;'>{short_name}</th>"
    html += "</tr>"
    
    for metric_id, metric in OUTPUT_METRICS.items():
        html += f"<tr style='border-bottom:1px solid #333;'><td style='color:#aaa; padding:8px;'>{metric['name']}</td>"
        for name in MODELS:
            count = output_metrics_agg[name][metric_id]
            pct = count / num_tests
            color = "#4ade80" if pct >= 0.8 else "#fbbf24" if pct >= 0.5 else "#f87171"
            icon = "✅" if pct == 1 else "⚠️" if pct > 0 else "❌"
            html += f"<td style='text-align:center; padding:8px;'><span style='color:{color};'>{icon} {count}/{num_tests}</span></td>"
        html += "</tr>"
    
    html += "</table></div>"
    display(HTML(html))

display_detailed_metrics(all_results)
# Out:
# <div style='background:#1a1a2e; padding:20px; border-radius:8px; margin:20px 0;'>
#     <h3 style='color:#eee; margin:0 0 15px 0;'>📊 Output Quality Metrics (per test)</h3>
#     <table style='width:100%; border-collapse:collapse; font-size:13px;'>
#         <tr style='background:#0f3460;'>
#             <th style='color:#eee; padding:8px; text-align:left;'>Metric</th><th style='color:#eee; padding:8px; text-align:center;'>Model A</th><th style='color:#eee; padding:8px; text-align:center;'>Model B</th><th style='color:#eee; padding:8px; text-align:center;'>Model C</th></tr><tr style='border-bottom:1px solid #333;'><td style='color:#aaa; padding:8px;'>Short Sentences</td><td style='text-align:center; padding:8px;'><span style='color:#f87171;'>❌ 0/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#f87171;'>❌ 0/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#fbbf24;'>⚠️ 2/3</span></td></tr><tr style='border-bottom:1px solid #333;'><td style='color:#aaa; padding:8px;'>Uses Bullet Points</td><td style='text-align:center; padding:8px;'><span style='color:#f87171;'>⚠️ 1/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#fbbf24;'>⚠️ 2/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#f87171;'>❌ 0/3</span></td></tr><tr style='border-bottom:1px solid #333;'><td style='color:#aaa; padding:8px;'>Clear Paragraphs</td><td style='text-align:center; padding:8px;'><span style='color:#fbbf24;'>⚠️ 2/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#4ade80;'>✅ 3/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#4ade80;'>✅ 3/3</span></td></tr><tr style='border-bottom:1px solid #333;'><td style='color:#aaa; padding:8px;'>No Intro/Outro Text</td><td style='text-align:center; padding:8px;'><span style='color:#4ade80;'>✅ 3/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#4ade80;'>✅ 3/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#4ade80;'>✅ 3/3</span></td></tr><tr style='border-bottom:1px solid #333;'><td style='color:#aaa; padding:8px;'>No XML/HTML Tags</td><td style='text-align:center; padding:8px;'><span style='color:#4ade80;'>✅ 3/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#4ade80;'>✅ 3/3</span></td><td style='text-align:center; padding:8px;'><span style='color:#4ade80;'>✅ 3/3</span></td></tr></table></div>

# %% [markdown]
# ---
# # 7. A/B Test: Compare Two Models
#
# Direct head-to-head comparison of the top 2 scoring models.

# %%
# Show available models
print("Available models:")
for i, name in enumerate(MODELS.keys()):
    print(f"  {i+1}. {name}")

# Use top 2 models from scorecard (run cell 18 first)
if "rankings" not in globals() or len(rankings) < 2:
    print("Run the scorecard cell first — need at least 2 ranked models.")
    MODEL_A = None
    MODEL_B = None
else:
    MODEL_A = rankings[0][0]  # #1 model name
    MODEL_B = rankings[1][0]  # #2 model name

    print("Scorecard top 2:")
    for rank, (name, model_id, quality, sim, combined) in enumerate(rankings[:2], 1):
        print(f"  #{rank}: {name} ({model_id}) — combined {combined:.0%}")

if MODEL_A and MODEL_B:
    # Count wins
    a_wins = 0
    b_wins = 0
    ties = 0
    
    print(f"\n⚔️ A/B Test: {MODEL_A} vs {MODEL_B}\n")
    
    for test_name in TEST_TEXTS:
        score_a = all_results[test_name][MODEL_A]["output_eval"]["_score"]
        score_b = all_results[test_name][MODEL_B]["output_eval"]["_score"]
        sim_a = all_results[test_name][MODEL_A]["similarity"]
        sim_b = all_results[test_name][MODEL_B]["similarity"]
        
        # Combined score for comparison
        combined_a = (score_a * 0.7) + (sim_a * 0.3)
        combined_b = (score_b * 0.7) + (sim_b * 0.3)
        
        if combined_a > combined_b:
            a_wins += 1
            winner = f"🅰️ {MODEL_A}"
        elif combined_b > combined_a:
            b_wins += 1
            winner = f"🅱️ {MODEL_B}"
        else:
            ties += 1
            winner = "🤝 Tie"
        
        print(f"  {test_name}: {winner}")
        print(f"      A: {score_a:.0%} quality, {sim_a:.1%} sim → {combined_a:.0%}")
        print(f"      B: {score_b:.0%} quality, {sim_b:.1%} sim → {combined_b:.0%}")
    
    print(f"\n📊 Results: {MODEL_A} wins {a_wins}, {MODEL_B} wins {b_wins}, Ties: {ties}")
    overall_winner = MODEL_A if a_wins > b_wins else MODEL_B if b_wins > a_wins else "Tie"
    print(f"🏆 Overall Winner: {overall_winner}")
else:
    print("⚠️ Need at least 2 models for A/B testing")
# Out:
# Available models:
#   1. Model A (replacement 8B)
#   2. Model B (replacement 70B)
#   3. Model C (preview 27B)
# Scorecard top 2:
#   #1: Model C (preview 27B) (qwen/qwen3.6-27b) — combined 57%
#   #2: Model B (replacement 70B) (openai/gpt-oss-120b) — combined 51%
#
# ⚔️ A/B Test: Model C (preview 27B) vs Model B (replacement 70B)
#
#   Legal: 🅱️ Model B (replacement 70B)
#       A: 50% quality, 19.1% sim → 41%
#       B: 50% quality, 28.9% sim → 44%
#   Medical: 🅰️ Model C (preview 27B)
#       A: 83% quality, 14.5% sim → 63%
#       B: 67% quality, 12.6% sim → 50%
#   Bureaucratic: 🅰️ Model C (preview 27B)
#       A: 83% quality, 34.7% sim → 69%
#       B: 67% quality, 44.7% sim → 60%
#
# 📊 Results: Model C (preview 27B) wins 2, Model B (replacement 70B) wins 1, Ties: 0
# 🏆 Overall Winner: Model C (preview 27B)

# %% [markdown]
# ---
# # 8. Side-by-Side Output Comparison
#
# View full outputs from both models for manual inspection.

# %%
def display_full_outputs(test_name: str):
    """Display full outputs from all models for a given test."""
    
    html = f"""<div style='background:#1a1a2e; padding:20px; border-radius:8px; margin:20px 0;'>
    <h3 style='color:#eee; margin:0 0 10px 0;'>📝 Full Outputs: {test_name}</h3>
    <div style='background:#0f3460; padding:10px; border-radius:4px; margin-bottom:15px;'>
        <div style='color:#888; font-size:10px; text-transform:uppercase;'>Original Text</div>
        <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; margin:5px 0 0 0;'>{TEST_TEXTS[test_name]}</pre>
    </div>
    <div style='display:flex; gap:15px; flex-wrap:wrap;'>"""
    
    for model_name, data in all_results[test_name].items():
        score = data["output_eval"]["_score"]
        sim = data["similarity"]
        score_color = "#4ade80" if score >= 0.8 else "#fbbf24" if score >= 0.6 else "#f87171"
        
        html += f"""
        <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
            <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
                <strong style='color:#e0e0e0;'>{model_name}</strong>
                <span style='background:{score_color}; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>{score:.0%}</span>
            </div>
            <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: {sim:.1%}</div>
            <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>{data["output"]}</pre>
        </div>"""
    
    html += "</div></div>"
    display(HTML(html))

# Display full outputs for each test
for test_name in TEST_TEXTS:
    display_full_outputs(test_name)
# Out:
# <div style='background:#1a1a2e; padding:20px; border-radius:8px; margin:20px 0;'>
#     <h3 style='color:#eee; margin:0 0 10px 0;'>📝 Full Outputs: Legal</h3>
#     <div style='background:#0f3460; padding:10px; border-radius:4px; margin-bottom:15px;'>
#         <div style='color:#888; font-size:10px; text-transform:uppercase;'>Original Text</div>
#         <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; margin:5px 0 0 0;'>The obligations contained herein shall remain in full force and effect indefinitely,
# notwithstanding the termination of this Agreement, until such time as the Confidential Information
# no longer qualifies as confidential under applicable law.</pre>
#     </div>
#     <div style='display:flex; gap:15px; flex-wrap:wrap;'>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
#                 <strong style='color:#e0e0e0;'>Model A (replacement 8B)</strong>
#                 <span style='background:#f87171; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>33%</span>
#             </div>
#             <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: 24.5%</div>
#             <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>Your duties stay active forever, even after this agreement ends.
# They keep working until the confidential information is no longer protected by law.</pre>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
#                 <strong style='color:#e0e0e0;'>Model B (replacement 70B)</strong>
#                 <span style='background:#f87171; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>50%</span>
#             </div>
#             <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: 28.9%</div>
#             <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>The duties stay in force forever.
#
# They keep working even after this agreement ends.
#
# They stop only when the secret information is no longer secret under the law.</pre>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
#                 <strong style='color:#e0e0e0;'>Model C (preview 27B)</strong>
#                 <span style='background:#f87171; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>50%</span>
#             </div>
#             <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: 19.1%</div>
#             <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>Your duty to keep secrets lasts forever.
#
# This rule stays even if the contract ends.
#
# You must keep the information secret.
#
# You can stop when the law says it is no longer secret.</pre>
#         </div></div></div>
# <div style='background:#1a1a2e; padding:20px; border-radius:8px; margin:20px 0;'>
#     <h3 style='color:#eee; margin:0 0 10px 0;'>📝 Full Outputs: Medical</h3>
#     <div style='background:#0f3460; padding:10px; border-radius:4px; margin-bottom:15px;'>
#         <div style='color:#888; font-size:10px; text-transform:uppercase;'>Original Text</div>
#         <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; margin:5px 0 0 0;'>Patients should take the prescribed medication twice daily with food to minimize
# gastrointestinal discomfort. If adverse reactions occur, discontinue use immediately and consult
# your healthcare provider.</pre>
#     </div>
#     <div style='display:flex; gap:15px; flex-wrap:wrap;'>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
#                 <strong style='color:#e0e0e0;'>Model A (replacement 8B)</strong>
#                 <span style='background:#f87171; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>50%</span>
#             </div>
#             <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: 15.9%</div>
#             <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>Take the medicine twice a day.
#
# Eat food when you take it. This helps your stomach feel better.
#
# If you feel sick or have bad reactions, stop taking it right away. Call your doctor.</pre>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
#                 <strong style='color:#e0e0e0;'>Model B (replacement 70B)</strong>
#                 <span style='background:#fbbf24; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>67%</span>
#             </div>
#             <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: 12.6%</div>
#             <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>Take the medicine two times each day.
#
# Eat food when you take it. This helps your stomach feel better.
#
# If you feel bad after taking it:
#
# * Stop taking the medicine right away.
# * Call your doctor.</pre>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
#                 <strong style='color:#e0e0e0;'>Model C (preview 27B)</strong>
#                 <span style='background:#4ade80; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>83%</span>
#             </div>
#             <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: 14.5%</div>
#             <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>Take your medicine two times a day.
#
# Eat food when you take it. This helps your stomach.
#
# Stop taking the medicine if you feel sick.
#
# Call your doctor right away.</pre>
#         </div></div></div>
# <div style='background:#1a1a2e; padding:20px; border-radius:8px; margin:20px 0;'>
#     <h3 style='color:#eee; margin:0 0 10px 0;'>📝 Full Outputs: Bureaucratic</h3>
#     <div style='background:#0f3460; padding:10px; border-radius:4px; margin-bottom:15px;'>
#         <div style='color:#888; font-size:10px; text-transform:uppercase;'>Original Text</div>
#         <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; margin:5px 0 0 0;'>For the application of housing benefit, a fully completed application form
# must be submitted to the responsible authority. The required proof of income and the rent
# certificate must be attached. Processing time is usually six to eight weeks.</pre>
#     </div>
#     <div style='display:flex; gap:15px; flex-wrap:wrap;'>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
#                 <strong style='color:#e0e0e0;'>Model A (replacement 8B)</strong>
#                 <span style='background:#fbbf24; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>67%</span>
#             </div>
#             <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: 43.7%</div>
#             <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>When you apply for housing help:
#
# * Fill out the whole application form.
# * Attach proof of your income.
# * Attach the rent certificate.
#
# The office will take about six to eight weeks to finish your application.</pre>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
#                 <strong style='color:#e0e0e0;'>Model B (replacement 70B)</strong>
#                 <span style='background:#fbbf24; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>67%</span>
#             </div>
#             <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: 44.7%</div>
#             <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>When you apply for housing benefit:
#
# * Fill out the whole form.
# * Send it to the right office.
# * Add proof of your income.
# * Add the rent certificate.
#
# The office will usually take six to eight weeks to decide.</pre>
#         </div>
#         <div style='flex:1; min-width:300px; background:#0f3460; padding:12px; border-radius:6px;'>
#             <div style='display:flex; justify-content:space-between; margin-bottom:8px;'>
#                 <strong style='color:#e0e0e0;'>Model C (preview 27B)</strong>
#                 <span style='background:#4ade80; color:#000; padding:2px 8px; border-radius:10px; font-size:11px;'>83%</span>
#             </div>
#             <div style='color:#888; font-size:10px; margin-bottom:8px;'>Similarity: 34.7%</div>
#             <pre style='color:#ddd; font-size:12px; white-space:pre-wrap; background:#1a1a2e; padding:10px; border-radius:4px; margin:0;'>You want housing benefit.
#
# You must send a form.
#
# Fill in the whole form.
#
# Send it to the right office.
#
# Add proof of your income.
#
# Add your rent certificate.
#
# It takes six to eight weeks.</pre>
#         </div></div></div>

# %% [markdown]
# From this it looks like qwen might be best for us, although I am not convinced by the output that the translations are really that accurate. For example with the legal example the overuse and drift in context of the word secret is weird. Since openai/gpt-oss-120b seems lik it keeps context better and is considered a production model I will switch to that one and review over the next couple days. I think this might be an indication that it's time for us to also update our sample test text examples.

# %% [markdown]
# ---
# # Notes for Future Use
#
# ## Adding New Models
#
# 1. Add your model to the `MODELS` dictionary in Section 2:
#
# ```python
# MODELS = {
#     "Model A (GPT-OSS 20B)": "openai/gpt-oss-20b",
#     "Model B (GPT-OSS 120B)": "openai/gpt-oss-120b",
#     "Model C (Qwen 3.6 27B)": "qwen/qwen3.6-27b",
# }
# ```
#
# 2. Re-run all cells
# 3. Check the scorecard to see how it compares
#
# ## Available Groq Models (as of 2026-08)
#
# Llama 3.1 8B Instant and Llama 3.3 70B Versatile were shut down on 2026-08-16.
#
# | Model ID | Description | Notes |
# |----------|-------------|-------|
# | `openai/gpt-oss-20b` | Groq replacement for Llama 3.1 8B Instant | Production, fastest |
# | `openai/gpt-oss-120b` | Groq replacement for Llama 3.3 70B | Production, higher quality |
# | `qwen/qwen3.6-27b` | Qwen 3.6 27B | Preview, stronger multilingual |
#
# ## Scoring Breakdown
#
# **Combined Score** = (Output Quality × 0.7) + (TF-IDF Similarity × 0.3)
#
# | Component | Weight | What It Measures |
# |-----------|--------|------------------|
# | Output Quality | 70% | Rule adherence (sentences, bullets, formatting) |
# | TF-IDF Similarity | 30% | Meaning preservation (lexical overlap) |
#
# ## Output Quality Metrics
#
# | Metric | Description | Weight |
# |--------|-------------|--------|
# | Short Sentences | Max 10 words per sentence | 2x |
# | Uses Bullets | Has bullet points or numbered lists | 1x |
# | Clear Paragraphs | Has blank lines between sections | 1x |
# | No Intro Text | Starts directly without "Here is..." | 1x |
# | No XML Tags | No markup in output | 1x |

# %% [markdown]
# # Model Scoring Template
#
# Compare and evaluate different **models** using the winning prompt from prompt evaluation.
#
# ## What This Template Does
#
# 1. **Fixed Prompt** - Uses Prompt B (Structured) - the winner from prompt evaluation
# 2. **Model Comparison** - Tests multiple models on the same prompt and test texts
# 3. **Output Quality Metrics** - Measures how well each model produces Easy Language output
# 4. **A/B Testing** - Directly compare two models to pick the winner
#
# ## Key Difference from Prompt Evaluation
#
# | Template | Fixed Variable | Changeable Variable |
# |----------|----------------|---------------------|
# | Prompt Evaluation | Model | Prompts |
# | **Model Scoring** | **Prompt** | **Models** |
